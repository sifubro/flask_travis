# %% [markdown]
# #### https://www.youtube.com/watch?v=0nr6TPKlrN0&ab_channel=Jay
#
# #### https://www.youtube.com/watch?v=d1DKT2xk_dM&ab_channel=Jay
#
# ### Todo:
# - Render/Host the website using Apache server or AWS
# -
#
# How can we display uploaded image on flask <br>
# https://roytuts.com/upload-and-display-image-using-python-flask/

# %%
from keras.preprocessing.image import load_img, img_to_array
#from keras.applications.vgg16 import preprocess_input, decode_predictions #VGG16
#from keras.applications.xception import preprocess_input, decode_predictions, Xception
from keras.applications.mobilenet_v2 import preprocess_input, decode_predictions, MobileNetV2

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
model = MobileNetV2()

# %%
model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# ...

# %%
imgpath = 'C://Users/30694/Downloads/rallou1.jpg'

#224 for vgg16 and mobilenet
#299 for xception
img = load_img(imgpath, target_size=(224,224))  
img = img_to_array(img)
img = img.reshape((1, img.shape[0],img.shape[1], img.shape[2] ))
img = preprocess_input(img)

# %%
img.shape
# Out:
# (1, 224, 224, 3)

# %%
yhat = model.predict(img)

# %%
label = decode_predictions(yhat)
label
# Out:
# [[('n04399382', 'teddy', 0.41133112),
#   ('n02869837', 'bonnet', 0.15921456),
#   ('n01943899', 'conch', 0.075716294),
#   ('n01944390', 'snail', 0.051804088),
#   ('n02808304', 'bath_towel', 0.01873402)]]

# %%
label[0]
# Out:
# 'n04399382'

# %%
label[0][1]
# Out:
# ('n02869837', 'bonnet', 0.15921456)

# %%
label = label[0][0]
label2 = label[0][1]
label3 = label[0][2]

# %%
label2
# Out:
# '0'

# %%
classification = "{} , {} \n {} , {} \n {} , {}".format(label[1], label[2]*100,label2[1], label2[2]*100, label3[1], label3[2]*100 )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-4ed85c47e49d> in <module>
# ----> 1 classification = "{} , {} \n {} , {} \n {} , {}".format(label[1], label[2]*100,label2[1], label2[2]*100, label3[1], label3[2]*100 )
#
# IndexError: string index out of range

# %%
label = decode_predictions(yhat)
label = label[0][0]

classification = "%s (%.2f%%)" %(label[1], label[2]*100)
classification
# Out:
# ...
# 40960/35363 [==================================] - 0s 1us/step
# 'teddy (41.13%)'
